# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
car_data_df=pd.read_csv(r"C:\Users\apurba.mondal\Documents\result_car_data.csv")

# %%
car_data_df.rename(columns={'OWNER.1':'OWNER'},inplace=True)

# %%
car_data_df['BRAND']=car_data_df['CAR_NAME'].str.split(' ').str[0]

# %%
car_data_df
# Out:
#       SALES_ID                                         CAR_NAME  YEAR  \
# 0         1651                      Tata Tiago 1.05 Revotorq XE  2017
# 1         5466                      Tata Tiago 1.05 Revotorq XE  2018
# 2          749                      Tata Tiago 1.05 Revotorq XM  2017
# 3         7101                      Tata Tiago 1.05 Revotorq XT  2016
# 4         5434                      Tata Tiago 1.05 Revotorq XT  2017
# ...        ...                                              ...   ...
# 7901      4535  Volkswagen Polo 2015-2019 1.0 MPI Highline Plus  2018
# 7902      1684  Volkswagen Polo 2015-2019 1.0 MPI Highline Plus  2018
# 7903      4747      Volkswagen Polo 2015-2019 1.0 MPI Trendline  2018
# 7904      3357      Volkswagen Polo 2015-2019 1.0 MPI Trendline  2018
# 7905      2719      Volkswagen Polo 2015-2019 1.0 MPI Trendline  2019
#
#       SELLING_PRICE  KM_DRIVEN    FUEL SELLER_TYPE        OWNER TRANSMISSION  \
# 0            325000     120000  Diesel  Individual  First Owner       Manual
# 1            450000      90000  Diesel  Individual  First Owner       Manual
# 2            360000      50000  Diesel  Individual  First Owner       Manual
# 3            400000      60000  Diesel  Individual  First Owner       Manual
# 4            450000      80000  Diesel  Individual  First Owner       Manual
# ...             ...        ...     ...         ...          ...          ...
# 7901         678000      17000  Petrol  Individual  First Owner       Manual
# 7902         678000      17000  Petrol  Individual  First Owner       Manual
# 7903         560000      14495  Petrol      Dealer  First Owner       Manual
# 7904         560000      14495  Petrol      Dealer  First Owner       Manual
# 7905         570000       5000  Petrol  Individual  First Owner       Manual
#
#          MILEAGE CAR_ENGINE MAX_POWER  SEAT  POSTAL_CODE   CITY_NAME  \
# 0     27.28 kmpl    1047 CC    69 bhp     5       452003      Indore
# 1     27.28 kmpl    1047 CC    69 bhp     5       431001  Aurangabad
# 2     27.28 kmpl    1047 CC    69 bhp     5       680001    Thrissur
# 3     27.28 kmpl    1047 CC    69 bhp     5       248001    Dehradun
# 4     27.28 kmpl    1047 CC    69 bhp     5       641043  Coimbatore
# ...          ...        ...       ...   ...          ...         ...
# 7901  18.78 kmpl     999 CC    75 bhp     5       141003    Ludhiana
# 7902  18.78 kmpl     999 CC    75 bhp     5       641043  Coimbatore
# 7903  18.78 kmpl     999 CC    75 bhp     5       680001    Thrissur
# 7904  18.78 kmpl     999 CC    75 bhp     5       560063   Bangalore
# 7905  18.78 kmpl     999 CC    75 bhp     5       632001     Vellore
#
#           STATE_NAME  REGIONS SOLD       BRAND
# 0     Madhya Pradesh  Central    Y        Tata
# 1        Maharashtra     West    N        Tata
# 2             Kerala    South    Y        Tata
# 3        Uttarakhand  Central    N        Tata
# 4         Tamil Nadu    South    N        Tata
# ...              ...      ...  ...         ...
# 7901          Punjab    North    N  Volkswagen
# 7902      Tamil Nadu    South    Y  Volkswagen
# 7903          Kerala    South    N  Volkswagen
# 7904       Karnataka    South    N  Volkswagen
# 7905      Tamil Nadu    South    N  Volkswagen
#
# [7906 rows x 19 columns]

# %% [markdown]
# ### Question C::----

# %%
brand_count_df=car_data_df.groupby('BRAND')[['SALES_ID']] .count(
).rename(columns={'SALES_ID':'NO_OF_SALES'}).sort_values(
    'NO_OF_SALES',ascending=False)
brand_count_df
# Out:
#                NO_OF_SALES
# BRAND
# Maruti                2367
# Hyundai               1360
# Mahindra               758
# Tata                   719
# Honda                  466
# Toyota                 452
# Ford                   388
# Chevrolet              230
# Renault                228
# Volkswagen             185
# BMW                    118
# Skoda                  104
# Nissan                  81
# Jaguar                  71
# Volvo                   67
# Datsun                  65
# Mercedes-Benz           54
# Fiat                    41
# Audi                    40
# Lexus                   34
# Jeep                    31
# Mitsubishi              14
# Land                     6
# Force                    6
# Isuzu                    5
# Ambassador               4
# Kia                      4
# MG                       3
# Daewoo                   3
# Opel                     1
# Ashok                    1

# %%
plt.figure(figsize=(40,20))
plt.bar(brand_count_df.index,brand_count_df.NO_OF_SALES)
plt.xlabel('BRAND')
plt.ylabel('NO_OF_SALES');
plt.title('COUNT OF SALES PER BRAND');

# %% [markdown]
# ## Question D ::--

# %%
region_df=car_data_df.groupby('REGIONS').agg({'SALES_ID':'count','SELLING_PRICE':'sum'}).rename(
columns={'SALES_ID':'NUMBER_OF_SALES','SELLING_PRICE':'TOTAL_REVENUE'}).sort_values('REGIONS',ascending=True)

# %%
state_df1=car_data_df.groupby('STATE_NAME').agg({'SALES_ID':'count','SELLING_PRICE':'sum'}).rename(
columns={'SALES_ID':'NUMBER_OF_SALES','SELLING_PRICE':'TOTAL_REVENUE'}).sort_values('NUMBER_OF_SALES',ascending=False)

# %%
state_df2=car_data_df.groupby('STATE_NAME').agg({'SALES_ID':'count','SELLING_PRICE':'sum'}).rename(
columns={'SALES_ID':'NUMBER_OF_SALES','SELLING_PRICE':'TOTAL_REVENUE'}).sort_values('TOTAL_REVENUE',ascending=False).head(7)

# %%
city_df1=car_data_df.groupby('CITY_NAME').agg({'SALES_ID':'count','SELLING_PRICE':'sum'}).rename(
columns={'SALES_ID':'NUMBER_OF_SALES','SELLING_PRICE':'TOTAL_REVENUE'}).sort_values('NUMBER_OF_SALES',ascending=False).head(15)

# %%
city_df2=car_data_df.groupby('CITY_NAME').agg({'SALES_ID':'count','SELLING_PRICE':'sum'}).rename(
columns={'SALES_ID':'NUMBER_OF_SALES','SELLING_PRICE':'TOTAL_REVENUE'}).sort_values('TOTAL_REVENUE',ascending=False).head(7)

# %%
location_df=car_data_df.groupby(['REGIONS','STATE_NAME','CITY_NAME']).agg({'SALES_ID':'count','SELLING_PRICE':'sum'}).rename(
columns={'SALES_ID':'NUMBER_OF_SALES','SELLING_PRICE':'TOTAL_REVENUE'}).sort_values(
    ['REGIONS','STATE_NAME','NUMBER_OF_SALES','CITY_NAME'],ascending=[True,True,False,False])
location_df
# Out:
#                                         NUMBER_OF_SALES  TOTAL_REVENUE
# REGIONS    STATE_NAME     CITY_NAME
# Central    Madhya Pradesh Indore                    257      159424990
#            Uttar Pradesh  Noida                     303      211556992
#                           kanpur                    247      146371497
#            Uttarakhand    Dehradun                  280      163735253
# East       Bihar          Patna                     257      189797583
#            Jharkhand      Ranchi                    276      176200987
#                           Jamshedpur                247      179004995
#            Odisha         Bhubaneshwar              255      159331492
#            West Bengal    Kolkata                   268      161600988
# North      Delhi          Delhi                     320      214853990
#            Punjab         Ludhiana                  249      159501995
#            Rajasthan      Jaipur                    274      160507492
# North East Sikkim         Gangtok                   257      164425989
# South      Andhra Pradesh Nellore                   281      206429984
#            Karnataka      Mysore                    279      189105943
#                           Mangalore                 279      173242139
#                           Bangalore                 276      164815343
#            Kerala         Kochi                     279      188043948
#                           Thrissur                  270      180375992
#            Tamil Nadu     Coimbatore                294      184818982
#                           Vellore                   293      190692988
#                           Chennai                   285      181171991
#            Telangana      Hyderabad                 262      158189991
# West       Gujarat        Ahmedabad                 278      187822698
#                           Vadodara                  272      204684988
#                           Surat                     242      160665990
#            Maharashtra    Mumbai                    298      193084984
#                           Aurangabad                278      192231987
#                           Pune                      250      135735086

# %%
fig,axes=plt.subplots(1,3,figsize=(25,8))

##Chart 1:--
axes[0].set_title('NO OF SALES PER REGION')
sns.barplot(x=region_df.index,y=region_df.NUMBER_OF_SALES,ax=axes[0])
axes[0].plot(region_df.index,region_df.NUMBER_OF_SALES,'s--r');

##chart 2:--
axes[1].set_title('SALES PER STATE')
axes[1].pie(state_df1.NUMBER_OF_SALES,labels=state_df1.index);

##chart 3:--
axes[2].set_title('NO OF SALES PER CITY(Showing top 15 city)')
sns.barplot(y=city_df1.index,x=city_df1.NUMBER_OF_SALES,ax=axes[2]);
axes[2].plot(city_df1.NUMBER_OF_SALES,city_df1.index,'s--r');



# ##chart 4:--
# axes[1,0].set_title('TOTAL REVENUE PER REGION')
# sns.barplot(x=region_df.index,y=region_df.TOTAL_REVENUE,ax=axes[1,0])
# axes[1,0].set_ylabel('TOTAL REVENUE  X  l0+e9')
# axes[1,0].plot(region_df.index,region_df.TOTAL_REVENUE,'s--r');

# ##chart 5:--
# axes[1,1].set_title('TOTAL REVENUE PER STATE(Showing top 7 state)')
# sns.barplot(x=state_df2.index,y=state_df2.TOTAL_REVENUE,ax=axes[1,1])
# axes[1,1].set_ylabel('TOTAL REVENUE  X  10+e8')
# axes[1,1].plot(state_df2.index,state_df2.TOTAL_REVENUE,'s--r');

# ##chart 6:--
# axes[1,2].set_title('TOTAL REVENUE PER CITY(Showing top 7 city)')
# sns.barplot(x=city_df2.index,y=city_df2.TOTAL_REVENUE,ax=axes[1,2])
# axes[1,2].set_ylabel('TOTAL REVENUE  X  10+e8')
# axes[1,2].plot(city_df2.index,city_df2.TOTAL_REVENUE,'s--r');

# %%
car_data_df.CAR_ENGINE=car_data_df.CAR_ENGINE.str.split(" ").str[0]
car_data_df.CAR_ENGINE=car_data_df.CAR_ENGINE.astype(int)

# %%
for i in car_data_df.index:
    if str(car_data_df.MILEAGE[i]).endswith("km/kg"):
        car_data_df.MILEAGE[i]=float(car_data_df.MILEAGE[i].split(' ')[0])*1.4
    elif str(car_data_df.MILEAGE[i]).endswith("kmpl"):
        car_data_df.MILEAGE[i]=float(car_data_df.MILEAGE[i].split(' ')[0])
car_data_df.MILEAGE=car_data_df.MILEAGE.astype(float)
# Out:
# C:\Users\apurba.mondal\AppData\Local\Temp\ipykernel_11632\1886968898.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_data_df.MILEAGE[i]=float(car_data_df.MILEAGE[i].split(' ')[0])
# C:\Users\apurba.mondal\AppData\Local\Temp\ipykernel_11632\1886968898.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_data_df.MILEAGE[i]=float(car_data_df.MILEAGE[i].split(' ')[0])*1.4

# %%
car_data_df.MAX_POWER=car_data_df.MAX_POWER.str.split(" ").str[0]
car_data_df.MAX_POWER=car_data_df.MAX_POWER.astype(float)

# %%
car_data_df.shape
# Out:
# (7906, 19)

# %%
car_data_df.head(5)
# Out:
#    SALES_ID                     CAR_NAME  YEAR  SELLING_PRICE  KM_DRIVEN  \
# 0      1651  Tata Tiago 1.05 Revotorq XE  2017         325000     120000
# 1      5466  Tata Tiago 1.05 Revotorq XE  2018         450000      90000
# 2       749  Tata Tiago 1.05 Revotorq XM  2017         360000      50000
# 3      7101  Tata Tiago 1.05 Revotorq XT  2016         400000      60000
# 4      5434  Tata Tiago 1.05 Revotorq XT  2017         450000      80000
#
#      FUEL SELLER_TYPE        OWNER TRANSMISSION  MILEAGE  CAR_ENGINE  \
# 0  Diesel  Individual  First Owner       Manual    27.28        1047
# 1  Diesel  Individual  First Owner       Manual    27.28        1047
# 2  Diesel  Individual  First Owner       Manual    27.28        1047
# 3  Diesel  Individual  First Owner       Manual    27.28        1047
# 4  Diesel  Individual  First Owner       Manual    27.28        1047
#
#    MAX_POWER  SEAT  POSTAL_CODE   CITY_NAME      STATE_NAME  REGIONS SOLD  \
# 0       69.0     5       452003      Indore  Madhya Pradesh  Central    Y
# 1       69.0     5       431001  Aurangabad     Maharashtra     West    N
# 2       69.0     5       680001    Thrissur          Kerala    South    Y
# 3       69.0     5       248001    Dehradun     Uttarakhand  Central    N
# 4       69.0     5       641043  Coimbatore      Tamil Nadu    South    N
#
#   BRAND
# 0  Tata
# 1  Tata
# 2  Tata
# 3  Tata
# 4  Tata

# %%
car_corr_df=car_data_df[['SELLING_PRICE','YEAR','KM_DRIVEN','MILEAGE','CAR_ENGINE','MAX_POWER']]
car_corr_df
# Out:
#       SELLING_PRICE  YEAR  KM_DRIVEN  MILEAGE  CAR_ENGINE  MAX_POWER
# 0            325000  2017     120000    27.28        1047       69.0
# 1            450000  2018      90000    27.28        1047       69.0
# 2            360000  2017      50000    27.28        1047       69.0
# 3            400000  2016      60000    27.28        1047       69.0
# 4            450000  2017      80000    27.28        1047       69.0
# ...             ...   ...        ...      ...         ...        ...
# 7901         678000  2018      17000    18.78         999       75.0
# 7902         678000  2018      17000    18.78         999       75.0
# 7903         560000  2018      14495    18.78         999       75.0
# 7904         560000  2018      14495    18.78         999       75.0
# 7905         570000  2019       5000    18.78         999       75.0
#
# [7906 rows x 6 columns]

# %%
plt.matshow(car_corr_df.corr())
plt.xticks(range(len(car_corr_df.columns)),car_corr_df.columns)
plt.yticks(range(len(car_corr_df.columns)),car_corr_df.columns)
# plt.figure(figsize=(15,4))
plt.colorbar()
plt.show();

# %%
pd.plotting.scatter_matrix(car_corr_df,figsize=(20,20))
plt.show()
